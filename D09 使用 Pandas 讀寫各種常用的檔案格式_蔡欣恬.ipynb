# %% [markdown]
# # 讀取資料夾中 boston.csv 讀取其欄位 CHAS、NOX、RM，輸出成 .xlsx 檔案

# %%
import pandas as pd

# %%
# 得到資料夾的路徑
import os
path='D:\Hsintien_tsai\Python\InputFile'
path
# Out:
# 'D:\\Hsintien_tsai\\Python\\InputFile'

# %%
# 列出指定路徑底下所有檔案(包含資料夾)
allFileList = os.listdir(path)
allFileList
# Out:
# ['boston.csv']

# %%
path=path+'\\'+allFileList[0]
path
# Out:
# 'D:\\Hsintien_tsai\\Python\\InputFile\\boston.csv'

# %%
#讀取資料夾中boston.csv讀取其欄位CHAS、NOX、RM，輸出成.xlsx檔案
file=pd.read_csv(path,usecols=['CHAS','NOX','RM'])
file
# Out:
#      CHAS    NOX     RM
# 0     0.0  0.538  6.575
# 1     0.0  0.469  6.421
# 2     0.0  0.469  7.185
# 3     0.0  0.458  6.998
# 4     0.0  0.458  7.147
# ..    ...    ...    ...
# 501   0.0  0.573  6.593
# 502   0.0  0.573  6.120
# 503   0.0  0.573  6.976
# 504   0.0  0.573  6.794
# 505   0.0  0.573  6.030
#
# [506 rows x 3 columns]

# %%
file.to_excel('20210126_boston.xlsx')
